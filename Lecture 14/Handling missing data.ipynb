# %%
import numpy as np

# %%
a = np.array([[0, 1, 2],
             [3, 4, 5]])

# %%
a.sum(axis=0)
# Out:
# array([3, 5, 7])

# %%
a.shape
# Out:
# (2, 3)

# %%
import pandas as pd

# %%
df = pd.read_csv('melbourne.csv')

# %%
df.head()
# Out:
#        Suburb             Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford       68 Studley St      2    h        NaN     SS  Jellis
# 1  Abbotsford        85 Turner St      2    h  1480000.0      S  Biggin
# 2  Abbotsford     25 Bloomburg St      2    h  1035000.0      S  Biggin
# 3  Abbotsford  18/659 Victoria St      3    u        NaN     VB  Rounds
# 4  Abbotsford        5 Charles St      3    h  1465000.0     SP  Biggin
#
#          Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  03-09-2016       2.5    3067.0  ...       1.0  1.0     126.0           NaN
# 1  03-12-2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# 2  04-02-2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 3  04-02-2016       2.5    3067.0  ...       2.0  1.0       0.0           NaN
# 4  04-03-2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
#
# ...

# %% [markdown]
# Question. Find the number of missing values in each column.

# %%
df.isnull().sum(axis=0)
# Out:
# Suburb               0
# Address              0
# Rooms                0
# Type                 0
# Price             5151
# Method               0
# SellerG              0
# Date                 0
# Distance             1
# Postcode             1
# Bedroom2          4481
# Bathroom          4484
# Car               4626
# Landsize          6137
# BuildingArea     13529
# YearBuilt        12007
# CouncilArea       7891
# Lattitude         4304
# Longtitude        4304
# Regionname           1
# Propertycount        1
# dtype: int64

# %% [markdown]
# Question. Find the number of missing values in each row.

# %%
df.isnull().sum(axis=1)
# Out:
# 0        3
# 1        2
# 2        0
# 3        3
# 4        0
# 5        2
# 6        0
# 7        1
# 8        2
# 9        2
# 10       2
# 11       0
# 12       1
# 13       1
# 14       0
# 15       9
# 16       9
# 17       2
# 18       0
# 19       9
# 20       1
# 21       9
# 22       9
# 23       2
# 24       0
# 25       0
# 26       7
# 27       9
# 28       2
# 29       2
#         ..
# 23517    2
# 23518    3
# 23519    3
# 23520    2
# 23521    1
# 23522    4
# 23523    3
# 23524    3
# 23525    1
# 23526    2
# 23527    1
# 23528    5
# 23529    4
# 23530    5
# 23531    9
# 23532    1
# 23533    5
# 23534    2
# 23535    3
# 23536    4
# 23537    2
# 23538    1
# 23539    2
# 23540    2
# 23541    1
# 23542    2
# 23543    8
# 23544    4
# 23545    1
# 23546    2
# Length: 23547, dtype: int64

# %%
df.isnull()
# Out:
#        Suburb  Address  Rooms   Type  Price  Method  SellerG   Date  Distance  \
# 0       False    False  False  False   True   False    False  False     False
# 1       False    False  False  False  False   False    False  False     False
# 2       False    False  False  False  False   False    False  False     False
# 3       False    False  False  False   True   False    False  False     False
# 4       False    False  False  False  False   False    False  False     False
# 5       False    False  False  False  False   False    False  False     False
# 6       False    False  False  False  False   False    False  False     False
# 7       False    False  False  False   True   False    False  False     False
# 8       False    False  False  False   True   False    False  False     False
# 9       False    False  False  False   True   False    False  False     False
# 10      False    False  False  False  False   False    False  False     False
# ...

# %% [markdown]
# Question. Find the columns having atleast one missing value.

# %%
# any() and all()

# %%
df.isnull().any()
# Out:
# Suburb           False
# Address          False
# Rooms            False
# Type             False
# Price             True
# Method           False
# SellerG          False
# Date             False
# Distance          True
# Postcode          True
# Bedroom2          True
# Bathroom          True
# Car               True
# Landsize          True
# BuildingArea      True
# YearBuilt         True
# CouncilArea       True
# Lattitude         True
# Longtitude        True
# Regionname        True
# Propertycount     True
# dtype: bool

# %% [markdown]
# Question. Find the rows having atleast one missing value.

# %%
df.isnull().any(axis=1) # True if for a particular row, there is atleast one column with missing value
# Out:
# 0         True
# 1         True
# 2        False
# 3         True
# 4        False
# 5         True
# 6        False
# 7         True
# 8         True
# 9         True
# 10        True
# 11       False
# 12        True
# 13        True
# 14       False
# 15        True
# 16        True
# 17        True
# 18       False
# 19        True
# 20        True
# 21        True
# 22        True
# 23        True
# 24       False
# 25       False
# 26        True
# 27        True
# 28        True
# 29        True
#          ...
# 23517     True
# 23518     True
# 23519     True
# 23520     True
# 23521     True
# 23522     True
# 23523     True
# 23524     True
# 23525     True
# 23526     True
# 23527     True
# 23528     True
# 23529     True
# 23530     True
# 23531     True
# 23532     True
# 23533     True
# 23534     True
# 23535     True
# 23536     True
# 23537     True
# 23538     True
# 23539     True
# 23540     True
# 23541     True
# 23542     True
# 23543     True
# ...

# %% [markdown]
# Question. Find the columns with all missing values.

# %%
df.isnull().all(axis=0) #There are no columns with all missing values
# Out:
# Suburb           False
# Address          False
# Rooms            False
# Type             False
# Price            False
# Method           False
# SellerG          False
# Date             False
# Distance         False
# Postcode         False
# Bedroom2         False
# Bathroom         False
# Car              False
# Landsize         False
# BuildingArea     False
# YearBuilt        False
# CouncilArea      False
# Lattitude        False
# Longtitude       False
# Regionname       False
# Propertycount    False
# dtype: bool

# %% [markdown]
# Question. Find the rows with all missing values.

# %%
df.isnull().all(axis=1).sum() #there are no rows with all missing values
# Out:
# 0

# %%
df.isnull().sum(axis=1)
# Out:
# 0        3
# 1        2
# 2        0
# 3        3
# 4        0
# 5        2
# 6        0
# 7        1
# 8        2
# 9        2
# 10       2
# 11       0
# 12       1
# 13       1
# 14       0
# 15       9
# 16       9
# 17       2
# 18       0
# 19       9
# 20       1
# 21       9
# 22       9
# 23       2
# 24       0
# 25       0
# 26       7
# 27       9
# 28       2
# 29       2
#         ..
# 23517    2
# 23518    3
# 23519    3
# 23520    2
# 23521    1
# 23522    4
# 23523    3
# 23524    3
# 23525    1
# 23526    2
# 23527    1
# 23528    5
# 23529    4
# 23530    5
# 23531    9
# 23532    1
# 23533    5
# 23534    2
# 23535    3
# 23536    4
# 23537    2
# 23538    1
# 23539    2
# 23540    2
# 23541    1
# 23542    2
# 23543    8
# 23544    4
# 23545    1
# 23546    2
# Length: 23547, dtype: int64

# %%
# NaN -> Not a Number
# NaT -> Not a Timestamp

# %% [markdown]
# Question. Find the length of column for dataframe df.

# %%
#length of a column

# %%
len(df)
# Out:
# 23547

# %%
df.shape[0] # number of rows = length of a particular column
# Out:
# 23547

# %% [markdown]
# Question. Percentage of missing values in columns

# %%
round((df.isnull().sum() / df.shape[0])*100,3) # number of missing values in a column / length of a column
# Out:
# Suburb            0.000
# Address           0.000
# Rooms             0.000
# Type              0.000
# Price            21.875
# Method            0.000
# SellerG           0.000
# Date              0.000
# Distance          0.004
# Postcode          0.004
# Bedroom2         19.030
# Bathroom         19.043
# Car              19.646
# Landsize         26.063
# BuildingArea     57.455
# YearBuilt        50.992
# CouncilArea      33.512
# Lattitude        18.278
# Longtitude       18.278
# Regionname        0.004
# Propertycount     0.004
# dtype: float64

# %% [markdown]
# Question. Find the number of missing values in a column???

# %%
df.isnull().sum()
# Out:
# Suburb               0
# Address              0
# Rooms                0
# Type                 0
# Price             5151
# Method               0
# SellerG              0
# Date                 0
# Distance             1
# Postcode             1
# Bedroom2          4481
# Bathroom          4484
# Car               4626
# Landsize          6137
# BuildingArea     13529
# YearBuilt        12007
# CouncilArea       7891
# Lattitude         4304
# Longtitude        4304
# Regionname           1
# Propertycount        1
# dtype: int64

# %%
round(df.isnull().mean() * 100,2)
# Out:
# Suburb            0.00
# Address           0.00
# Rooms             0.00
# Type              0.00
# Price            21.88
# Method            0.00
# SellerG           0.00
# Date              0.00
# Distance          0.00
# Postcode          0.00
# Bedroom2         19.03
# Bathroom         19.04
# Car              19.65
# Landsize         26.06
# BuildingArea     57.46
# YearBuilt        50.99
# CouncilArea      33.51
# Lattitude        18.28
# Longtitude       18.28
# Regionname        0.00
# Propertycount     0.00
# dtype: float64

# %%
((df.shape[0] - df.count()) / df.shape[0] * 100).round(2)
# Out:
# Suburb            0.00
# Address           0.00
# Rooms             0.00
# Type              0.00
# Price            21.88
# Method            0.00
# SellerG           0.00
# Date              0.00
# Distance          0.00
# Postcode          0.00
# Bedroom2         19.03
# Bathroom         19.04
# Car              19.65
# Landsize         26.06
# BuildingArea     57.46
# YearBuilt        50.99
# CouncilArea      33.51
# Lattitude        18.28
# Longtitude       18.28
# Regionname        0.00
# Propertycount     0.00
# dtype: float64

# %%
df.dropna().shape[0]
# Out:
# 6196

# %%
df.shape[0]
# Out:
# 23547

# %%
#df.drop('BuildingArea', axis=1)

# %%
#df.drop('YearBuilt', axis=1)

# %%
#df.drop('CouncilArea', axis=1)

# %%
df.drop(['BuildingArea', 'CouncilArea', 'YearBuilt'], axis=1, inplace=True)

# %%
df
# Out:
#                Suburb              Address  Rooms Type      Price Method  \
# 0          Abbotsford        68 Studley St      2    h        NaN     SS
# 1          Abbotsford         85 Turner St      2    h  1480000.0      S
# 2          Abbotsford      25 Bloomburg St      2    h  1035000.0      S
# 3          Abbotsford   18/659 Victoria St      3    u        NaN     VB
# 4          Abbotsford         5 Charles St      3    h  1465000.0     SP
# 5          Abbotsford     40 Federation La      3    h   850000.0     PI
# 6          Abbotsford          55a Park St      4    h  1600000.0     VB
# 7          Abbotsford         16 Maugie St      4    h        NaN     SN
# 8          Abbotsford         53 Turner St      2    h        NaN      S
# 9          Abbotsford         99 Turner St      2    h        NaN      S
# 10         Abbotsford       129 Charles St      2    h   941000.0      S
# 11         Abbotsford         124 Yarra St      3    h  1876000.0      S
# ...

# %%
round(df.isnull().mean() * 100,2)
# Out:
# Suburb            0.00
# Address           0.00
# Rooms             0.00
# Type              0.00
# Price            21.88
# Method            0.00
# SellerG           0.00
# Date              0.00
# Distance          0.00
# Postcode          0.00
# Bedroom2         19.03
# Bathroom         19.04
# Car              19.65
# Landsize         26.06
# Lattitude        18.28
# Longtitude       18.28
# Regionname        0.00
# Propertycount     0.00
# dtype: float64

# %%
series = pd.Series([1, 2, 'hello', None, 456, np.nan], index=['a', 'b', 'c', 'd', 'e', 'f'])

# %%
series
# Out:
# a        1
# b        2
# c    hello
# d     None
# e      456
# f      NaN
# dtype: object

# %% [markdown]
# Question. Fill the position d with the value 59 and the position f with value 60

# %%
series.fillna({"d": 59, "f":60})
# Out:
# a        1
# b        2
# c    hello
# d       59
# e      456
# f       60
# dtype: object

# %% [markdown]
# Question. Find out the rows which have more than 5 missing values.

# %%
#length of a row in df
df.shape[1]-5+1 #rows with less than 5 missing values if we set this as thresh .
# Out:
# 14

# %%
df[df.isnull().sum(axis=1) > 5] #total number of missing values in a particular row
# Out:
#                   Suburb              Address  Rooms Type      Price Method  \
# 15            Abbotsford     217 Langridge St      3    h  1000000.0      S
# 16            Abbotsford      18a Mollison St      2    t   745000.0      S
# 19            Abbotsford  403/609 Victoria St      2    u   542000.0      S
# 21            Abbotsford    25/84 Trenerry Cr      2    u   760000.0     SP
# 22            Abbotsford    106/119 Turner St      1    u   481000.0     SP
# 27            Abbotsford    13/84 Trenerry Cr      1    u   500000.0      S
# 33            Abbotsford     250 Langridge St      2    t   847000.0      S
# 34            Abbotsford      16b Mollison St      2    h        NaN     PI
# 45            Abbotsford    65/80 Trenerry Cr      1    u   480000.0      S
# 46            Abbotsford  119/52 Nicholson St      1    u   423500.0      S
# 52            Abbotsford    49/84 Trenerry Cr      2    h   700000.0      S
# ...

# %%
round((len(df[df.isnull().sum(axis=1) > 5]) / df.shape[0])*100,2)
# Out:
# 18.17

# %%
df.isnull().sum(axis=1) <= 5
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
# 5         True
# 6         True
# 7         True
# 8         True
# 9         True
# 10        True
# 11        True
# 12        True
# 13        True
# 14        True
# 15       False
# 16       False
# 17        True
# 18        True
# 19       False
# 20        True
# 21       False
# 22       False
# 23        True
# 24        True
# 25        True
# 26        True
# 27       False
# 28        True
# 29        True
#          ...
# 23517     True
# 23518     True
# 23519     True
# 23520     True
# 23521     True
# 23522     True
# 23523     True
# 23524     True
# 23525     True
# 23526     True
# 23527     True
# 23528     True
# 23529     True
# 23530     True
# 23531    False
# 23532     True
# 23533     True
# 23534     True
# 23535     True
# 23536     True
# 23537     True
# 23538     True
# 23539     True
# 23540     True
# 23541     True
# 23542     True
# 23543     True
# ...

# %%
# drop the rows with atleast 5 missing values . atmost how many non-missing values they have? = length of row - 5 
# we are dropping the rows which have less than 13 non-missing values 
# because if there are more than 5 missing values -> there are less than 13 non-missing values 
df = df[df.isnull().sum(axis=1) <= 5]

# %%
df.shape
# Out:
# (19269, 18)

# %%
round(df.isnull().mean() * 100,2)
# Out:
# Suburb            0.00
# Address           0.00
# Rooms             0.00
# Type              0.00
# Price            21.71
# Method            0.00
# SellerG           0.00
# Date              0.00
# Distance          0.00
# Postcode          0.00
# Bedroom2          1.05
# Bathroom          1.07
# Car               1.81
# Landsize          9.65
# Lattitude         0.13
# Longtitude        0.13
# Regionname        0.00
# Propertycount     0.00
# dtype: float64

# %%
df1 = pd.read_csv('melbourne.csv')
df1.drop(['BuildingArea', 'CouncilArea', 'YearBuilt'], axis=1, inplace=True)

# %%
df1.shape
# Out:
# (23547, 18)

# %%
df1.isnull().sum()
# Out:
# Suburb              0
# Address             0
# Rooms               0
# Type                0
# Price            5151
# Method              0
# SellerG             0
# Date                0
# Distance            1
# Postcode            1
# Bedroom2         4481
# Bathroom         4484
# Car              4626
# Landsize         6137
# Lattitude        4304
# Longtitude       4304
# Regionname          1
# Propertycount       1
# dtype: int64

# %%
df1.shape[1]
# Out:
# 18

# %%
df1.dropna(thresh = df1.shape[1]-5) #atleast 13 non missing values
# Out:
#                Suburb              Address  Rooms Type      Price Method  \
# 0          Abbotsford        68 Studley St      2    h        NaN     SS
# 1          Abbotsford         85 Turner St      2    h  1480000.0      S
# 2          Abbotsford      25 Bloomburg St      2    h  1035000.0      S
# 3          Abbotsford   18/659 Victoria St      3    u        NaN     VB
# 4          Abbotsford         5 Charles St      3    h  1465000.0     SP
# 5          Abbotsford     40 Federation La      3    h   850000.0     PI
# 6          Abbotsford          55a Park St      4    h  1600000.0     VB
# 7          Abbotsford         16 Maugie St      4    h        NaN     SN
# 8          Abbotsford         53 Turner St      2    h        NaN      S
# 9          Abbotsford         99 Turner St      2    h        NaN      S
# 10         Abbotsford       129 Charles St      2    h   941000.0      S
# 11         Abbotsford         124 Yarra St      3    h  1876000.0      S
# ...

# %%
round(df.isnull().mean()*100, 2)
# Out:
# Suburb            0.00
# Address           0.00
# Rooms             0.00
# Type              0.00
# Price            21.71
# Method            0.00
# SellerG           0.00
# Date              0.00
# Distance          0.00
# Postcode          0.00
# Bedroom2          1.05
# Bathroom          1.07
# Car               1.81
# Landsize          9.65
# Lattitude         0.13
# Longtitude        0.13
# Regionname        0.00
# Propertycount     0.00
# dtype: float64

# %%
df.shape[0]*0.8
# Out:
# 15415.2

# %% [markdown]
# Question. Drop the rows which have missing Price values

# %%
df.dropna(subset=['Price'])
# Out:
#                Suburb              Address  Rooms Type      Price Method  \
# 1          Abbotsford         85 Turner St      2    h  1480000.0      S
# 2          Abbotsford      25 Bloomburg St      2    h  1035000.0      S
# 4          Abbotsford         5 Charles St      3    h  1465000.0     SP
# 5          Abbotsford     40 Federation La      3    h   850000.0     PI
# 6          Abbotsford          55a Park St      4    h  1600000.0     VB
# 10         Abbotsford       129 Charles St      2    h   941000.0      S
# 11         Abbotsford         124 Yarra St      3    h  1876000.0      S
# 14         Abbotsford        98 Charles St      2    h  1636000.0      S
# 17         Abbotsford   6/241 Nicholson St      1    u   300000.0      S
# 18         Abbotsford        10 Valiant St      2    h  1097000.0      S
# 23         Abbotsford   411/8 Grosvenor St      2    u   700000.0     VB
# 24         Abbotsford      40 Nicholson St      3    h  1350000.0     VB
# ...

# %%
df = df[df['Price'].notnull()] #True if value is present
# we have dropped the rows where price is missing

# %%
round(100*df.isnull().mean(), 2)
# Out:
# Suburb           0.00
# Address          0.00
# Rooms            0.00
# Type             0.00
# Price            0.00
# Method           0.00
# SellerG          0.00
# Date             0.00
# Distance         0.00
# Postcode         0.00
# Bedroom2         1.05
# Bathroom         1.07
# Car              1.76
# Landsize         9.83
# Lattitude        0.15
# Longtitude       0.15
# Regionname       0.00
# Propertycount    0.00
# dtype: float64

# %%
df.shape
# Out:
# (15086, 18)

# %%
df['Landsize'].describe()
# Out:
# count     13603.000000
# mean        558.116371
# std        3987.326586
# min           0.000000
# 25%         176.500000
# 50%         440.000000
# 75%         651.000000
# max      433014.000000
# Name: Landsize, dtype: float64

# %%
# drop rows containing landsize as nan
df = df[df['Landsize'].notnull()]

# %%
round(100*df.isnull().mean(), 2)
# Out:
# Suburb           0.00
# Address          0.00
# Rooms            0.00
# Type             0.00
# Price            0.00
# Method           0.00
# SellerG          0.00
# Date             0.00
# Distance         0.00
# Postcode         0.00
# Bedroom2         0.00
# Bathroom         0.01
# Car              0.46
# Landsize         0.00
# Lattitude        0.16
# Longtitude       0.16
# Regionname       0.00
# Propertycount    0.00
# dtype: float64

# %%
df['Lattitude'].describe()
# Out:
# count    13581.000000
# mean       -37.809204
# std          0.079257
# min        -38.182550
# 25%        -37.856820
# 50%        -37.802360
# 75%        -37.756400
# max        -37.408530
# Name: Lattitude, dtype: float64

# %%
df['Longtitude'].describe()
# Out:
# count    13581.000000
# mean       144.995221
# std          0.103913
# min        144.431810
# 25%        144.929600
# 50%        145.000100
# 75%        145.058320
# max        145.526350
# Name: Longtitude, dtype: float64

# %% [markdown]
# Question. Fill the columns lattitude and longitude with their mean

# %%
# series.fillna(series.mean(), inplace=True)

# %%
df['Lattitude'].fillna(df['Lattitude'].mean(), inplace=True)

# %%
df['Longtitude'].fillna(df['Longtitude'].mean(), inplace=True)

# %%
round(100*df.isnull().mean(), 2)
# Out:
# Suburb           0.00
# Address          0.00
# Rooms            0.00
# Type             0.00
# Price            0.00
# Method           0.00
# SellerG          0.00
# Date             0.00
# Distance         0.00
# Postcode         0.00
# Bedroom2         0.00
# Bathroom         0.01
# Car              0.46
# Landsize         0.00
# Lattitude        0.00
# Longtitude       0.00
# Regionname       0.00
# Propertycount    0.00
# dtype: float64

# %%
df['Bathroom'].describe()
# Out:
# count    13602.000000
# mean         1.534921
# std          0.691834
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          2.000000
# max          8.000000
# Name: Bathroom, dtype: float64

# %% [markdown]
# Question. Drop rows containing missing bathroom values

# %%
#df[df['Bathroom'].notnull()]

# %% [markdown]
# Question. Fill the bathroom missing values with 1

# %%
df['Bathroom'].fillna(1, inplace=True)

# %%
round(100*df.isnull().mean(), 2)
# Out:
# Suburb           0.00
# Address          0.00
# Rooms            0.00
# Type             0.00
# Price            0.00
# Method           0.00
# SellerG          0.00
# Date             0.00
# Distance         0.00
# Postcode         0.00
# Bedroom2         0.00
# Bathroom         0.00
# Car              0.46
# Landsize         0.00
# Lattitude        0.00
# Longtitude       0.00
# Regionname       0.00
# Propertycount    0.00
# dtype: float64

# %%
df['Car'].describe()
# Out:
# count    13540.000000
# mean         1.610414
# std          0.962244
# min          0.000000
# 25%          1.000000
# 50%          2.000000
# 75%          2.000000
# max         10.000000
# Name: Car, dtype: float64

# %% [markdown]
# Question. Replace missing values in car with median

# %%
df['Car'].fillna(df['Car'].median(), inplace=True) # or 2

# %%
round(100*df.isnull().mean(), 2)
# Out:
# Suburb           0.0
# Address          0.0
# Rooms            0.0
# Type             0.0
# Price            0.0
# Method           0.0
# SellerG          0.0
# Date             0.0
# Distance         0.0
# Postcode         0.0
# Bedroom2         0.0
# Bathroom         0.0
# Car              0.0
# Landsize         0.0
# Lattitude        0.0
# Longtitude       0.0
# Regionname       0.0
# Propertycount    0.0
# dtype: float64

# %%
df.shape[0] / 23547
# Out:
# 0.5776956724848176
