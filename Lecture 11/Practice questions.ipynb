# %%
import numpy as np
import pandas as pd

# %%
titanic = pd.read_csv('train.csv')

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic.shape
# Out:
# (891, 12)

# %% [markdown]
# Question. Names of all passengers who traveled in 3rd Class of the ship.

# %%
titanic.loc[titanic['Pclass']==3, ['Name', 'Age']]
# Out:
#                                                   Name   Age
# 0                              Braund, Mr. Owen Harris  22.0
# 2                               Heikkinen, Miss. Laina  26.0
# 4                             Allen, Mr. William Henry  35.0
# 5                                     Moran, Mr. James   NaN
# 7                       Palsson, Master. Gosta Leonard   2.0
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  27.0
# 10                     Sandstrom, Miss. Marguerite Rut   4.0
# 12                      Saundercock, Mr. William Henry  20.0
# 13                         Andersson, Mr. Anders Johan  39.0
# 14                Vestrom, Miss. Hulda Amanda Adolfina  14.0
# 16                                Rice, Master. Eugene   2.0
# 18   Vander Planke, Mrs. Julius (Emelia Maria Vande...  31.0
# 19                             Masselmani, Mrs. Fatima   NaN
# 22                         McGowan, Miss. Anna "Annie"  15.0
# ...

# %%
titanic.loc[titanic['Pclass']==3,'Name']
# Out:
# 0                                Braund, Mr. Owen Harris
# 2                                 Heikkinen, Miss. Laina
# 4                               Allen, Mr. William Henry
# 5                                       Moran, Mr. James
# 7                         Palsson, Master. Gosta Leonard
# 8      Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 10                       Sandstrom, Miss. Marguerite Rut
# 12                        Saundercock, Mr. William Henry
# 13                           Andersson, Mr. Anders Johan
# 14                  Vestrom, Miss. Hulda Amanda Adolfina
# 16                                  Rice, Master. Eugene
# 18     Vander Planke, Mrs. Julius (Emelia Maria Vande...
# 19                               Masselmani, Mrs. Fatima
# 22                           McGowan, Miss. Anna "Annie"
# 24                         Palsson, Miss. Torborg Danira
# 25     Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...
# ...

# %%
titanic1 = titanic.ix[titanic['Pclass']==3]
titanic['Name']
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
# 5                                       Moran, Mr. James
# 6                                McCarthy, Mr. Timothy J
# 7                         Palsson, Master. Gosta Leonard
# 8      Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9                    Nasser, Mrs. Nicholas (Adele Achem)
# ...

# %% [markdown]
# Question. Passengers who traveled in 3rd Class of the ship THAT SURVIVED.

# %%
mask = (titanic.Survived == 1) & (titanic.Pclass == 3)
titanic[mask]
# Out:
#      PassengerId  Survived  Pclass  \
# 2              3         1       3
# 8              9         1       3
# 10            11         1       3
# 19            20         1       3
# 22            23         1       3
# 25            26         1       3
# 28            29         1       3
# 32            33         1       3
# 36            37         1       3
# 39            40         1       3
# 44            45         1       3
# 47            48         1       3
# 65            66         1       3
# 68            69         1       3
# 74            75         1       3
# 79            80         1       3
# 81            82         1       3
# 82            83         1       3
# 85            86         1       3
# 106          107         1       3
# 107          108         1       3
# 109          110         1       3
# 125          126         1       3
# 127          128         1       3
# 128          129         1       3
# ...

# %%
titanic.loc[(titanic['Pclass']==3) & (titanic['Survived']==1)]
# Out:
#      PassengerId  Survived  Pclass  \
# 2              3         1       3
# 8              9         1       3
# 10            11         1       3
# 19            20         1       3
# 22            23         1       3
# 25            26         1       3
# 28            29         1       3
# 32            33         1       3
# 36            37         1       3
# 39            40         1       3
# 44            45         1       3
# 47            48         1       3
# 65            66         1       3
# 68            69         1       3
# 74            75         1       3
# 79            80         1       3
# 81            82         1       3
# 82            83         1       3
# 85            86         1       3
# 106          107         1       3
# 107          108         1       3
# 109          110         1       3
# 125          126         1       3
# 127          128         1       3
# 128          129         1       3
# ...

# %% [markdown]
# Question. Only gender, and age of passengers who traveled in 3rd Class of the ship THAT SURVIVED.

# %%
len(titanic[titanic['Sex']=='female'])
# Out:
# 314

# %%
titanic.loc[(titanic['Pclass']==3) & (titanic['Survived']==1),['Sex', 'Age']]
# Out:
#         Sex    Age
# 2    female  26.00
# 8    female  27.00
# 10   female   4.00
# 19   female    NaN
# 22   female  15.00
# 25   female  38.00
# 28   female    NaN
# 32   female    NaN
# 36     male    NaN
# 39   female  14.00
# 44   female  19.00
# 47   female    NaN
# 65     male    NaN
# 68   female  17.00
# 74     male  32.00
# 79   female  30.00
# 81     male  29.00
# 82   female    NaN
# 85   female  33.00
# 106  female  21.00
# 107    male    NaN
# 109  female    NaN
# 125    male  12.00
# 127    male  24.00
# 128  female    NaN
# 141  female  22.00
# 142  female  24.00
# 146    male  27.00
# 156  female  16.00
# 165    male   9.00
# ..      ...    ...
# 643    male    NaN
# 644  female   0.75
# 649  female  23.00
# 653  female    NaN
# 664    male  20.00
# 677  female  18.00
# 691  female   4.00
# 692    male    NaN
# 697  female    NaN
# 709    male    NaN
# 727  female    NaN
# 744    male  31.00
# 751    male   6.00
# 762    male  20.00
# 777  female   5.00
# ...

# %% [markdown]
# Question. Group the passengers by their gender and find out how many survived?

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
group = titanic.groupby('Sex')
group['Survived'].count()
# Out:
# Sex
# female    314
# male      577
# Name: Survived, dtype: int64

# %%
len(titanic[titanic['Sex']=='female'])
# Out:
# 314

# %%
x = titanic.groupby('Sex')
x['Survived'].count()
# Out:
# Sex
# female    314
# male      577
# Name: Survived, dtype: int64

# %%
x.size()
# Out:
# Sex
# female    314
# male      577
# dtype: int64

# %%
group['Survived'].sum()
# Out:
# Sex
# female    233
# male      109
# Name: Survived, dtype: int64

# %%
for key, groups in group:
    print(key)
    print(len(groups[groups['Survived']==1]))
# Out:
# female
# 233
# male
# 109

# %%
titanic[['Survived','Sex']][titanic['Survived'] == 1].groupby('Sex').count()
# Out:
#         Survived
# Sex
# female       233
# male         109

# %%
#group[(group['Survived']==1) ].count()

# %%
updated = titanic[titanic.Survived.isin([1])]
group = updated.groupby("Sex")
group["Survived"].count()
# Out:
# Sex
# female    233
# male      109
# Name: Survived, dtype: int64

# %% [markdown]
# Question. Convert the name of each passenger into uppercase and output all the columns.

# %%
titanic = pd.read_csv('train.csv')

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic['Name'] = titanic['Name'].str.upper()

# %%
#titanic1 = titanic['Name'].upper()
#titanic1

# %%
#titanic.Name

# %%
#pd.Series(['shivs', 'atul', 'rishabh', 'jeevan']).str.upper()

# %%
titanic['Name'] = titanic['Name'].apply(lambda x: x.upper())

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            BRAUND, MR. OWEN HARRIS    male  22.0      1
# 1  CUMINGS, MRS. JOHN BRADLEY (FLORENCE BRIGGS TH...  female  38.0      1
# 2                             HEIKKINEN, MISS. LAINA  female  26.0      0
# 3       FUTRELLE, MRS. JACQUES HEATH (LILY MAY PEEL)  female  35.0      1
# 4                           ALLEN, MR. WILLIAM HENRY    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
#titanic['Name'] 
#titanic.Name

# %%
titanic.Name.str.len()
# Out:
# 0      23
# 1      51
# 2      22
# 3      44
# 4      24
# 5      16
# 6      23
# 7      30
# 8      49
# 9      35
# 10     31
# 11     24
# 12     30
# 13     27
# 14     36
# 15     32
# 16     20
# 17     28
# 18     55
# 19     23
# 20     20
# 21     21
# 22     27
# 23     28
# 24     29
# 25     57
# 26     23
# 27     30
# 28     29
# 29     19
#        ..
# 861    27
# 862    51
# 863    33
# 864    22
# 865    24
# 866    28
# 867    36
# 868    27
# 869    31
# 870    17
# 871    48
# 872    24
# 873    27
# 874    37
# 875    32
# 876    29
# 877    20
# 878    18
# 879    45
# 880    44
# 881    18
# 882    28
# 883    29
# 884    22
# 885    36
# 886    21
# 887    28
# 888    40
# 889    21
# 890    19
# Name: Name, Length: 891, dtype: int64

# %%
titanic.apply(lambda x: len(x['Name']), axis=1) #x is a row!!!!
# Out:
# 0      23
# 1      51
# 2      22
# 3      44
# 4      24
# 5      16
# 6      23
# 7      30
# 8      49
# 9      35
# 10     31
# 11     24
# 12     30
# 13     27
# 14     36
# 15     32
# 16     20
# 17     28
# 18     55
# 19     23
# 20     20
# 21     21
# 22     27
# 23     28
# 24     29
# 25     57
# 26     23
# 27     30
# 28     29
# 29     19
#        ..
# 861    27
# 862    51
# 863    33
# 864    22
# 865    24
# 866    28
# 867    36
# 868    27
# 869    31
# 870    17
# 871    48
# 872    24
# 873    27
# 874    37
# 875    32
# 876    29
# 877    20
# 878    18
# 879    45
# 880    44
# 881    18
# 882    28
# 883    29
# 884    22
# 885    36
# 886    21
# 887    28
# 888    40
# 889    21
# 890    19
# Length: 891, dtype: int64

# %%
titanic['Name'].apply(lambda x: len(x))
# Out:
# 0      23
# 1      51
# 2      22
# 3      44
# 4      24
# 5      16
# 6      23
# 7      30
# 8      49
# 9      35
# 10     31
# 11     24
# 12     30
# 13     27
# 14     36
# 15     32
# 16     20
# 17     28
# 18     55
# 19     23
# 20     20
# 21     21
# 22     27
# 23     28
# 24     29
# 25     57
# 26     23
# 27     30
# 28     29
# 29     19
#        ..
# 861    27
# 862    51
# 863    33
# 864    22
# 865    24
# 866    28
# 867    36
# 868    27
# 869    31
# 870    17
# 871    48
# 872    24
# 873    27
# 874    37
# 875    32
# 876    29
# 877    20
# 878    18
# 879    45
# 880    44
# 881    18
# 882    28
# 883    29
# 884    22
# 885    36
# 886    21
# 887    28
# 888    40
# 889    21
# 890    19
# Name: Name, Length: 891, dtype: int64

# %% [markdown]
# Question. Find the longest name in each class.

# %%
groups = titanic.groupby('Pclass')

# %%
for key, group in groups:
    print(key)
    print(group['Name'])
# Out:
# 1
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 6                                McCarthy, Mr. Timothy J
# 11                              Bonnell, Miss. Elizabeth
# 23                          Sloper, Mr. William Thompson
# 27                        Fortune, Mr. Charles Alexander
# 30                              Uruchurtu, Don. Manuel E
# 31        Spencer, Mrs. William Augustus (Marie Eugenie)
# 34                               Meyer, Mr. Edgar Joseph
# 35                        Holverson, Mr. Alexander Oskar
# 52              Harper, Mrs. Henry Sleeper (Myna Haxtun)
# 54                        Ostby, Mr. Engelhart Cornelius
# 55                                     Woolner, Mr. Hugh
# 61                                   Icard, Miss. Amelie
# 62                           Harris, Mr. Henry Birkhardt
# 64                                 Stewart, Mr. Albert A
# ...

# %%
groups['Name'].apply(lambda x: x.str.len().max()) #x is a series .
# Out:
# Pclass
# 1    82
# 2    67
# 3    57
# Name: Name, dtype: int64

# %%
x = groups.get_group(1).Name.str.len().max()
y = groups.get_group(2).Name.str.len().max()
z = groups.get_group(3).Name.str.len().max()
print(x, y, z)
# Out:
# 82 67 57

# %%
for key, group in groups:
    print(key)
    print(group['Name']) #is a series 
    print('\n')
# Out:
# 1
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 6                                McCarthy, Mr. Timothy J
# 11                              Bonnell, Miss. Elizabeth
# 23                          Sloper, Mr. William Thompson
# 27                        Fortune, Mr. Charles Alexander
# 30                              Uruchurtu, Don. Manuel E
# 31        Spencer, Mrs. William Augustus (Marie Eugenie)
# 34                               Meyer, Mr. Edgar Joseph
# 35                        Holverson, Mr. Alexander Oskar
# 52              Harper, Mrs. Henry Sleeper (Myna Haxtun)
# 54                        Ostby, Mr. Engelhart Cornelius
# 55                                     Woolner, Mr. Hugh
# 61                                   Icard, Miss. Amelie
# 62                           Harris, Mr. Henry Birkhardt
# 64                                 Stewart, Mr. Albert A
# ...

# %%
x = titanic[['Name', 'Pclass']].apply(lambda x: [len(x['Name']), x['Pclass']], axis = 1)

# %%
x
# Out:
# 0      [23, 3]
# 1      [51, 1]
# 2      [22, 3]
# 3      [44, 1]
# 4      [24, 3]
# 5      [16, 3]
# 6      [23, 1]
# 7      [30, 3]
# 8      [49, 3]
# 9      [35, 2]
# 10     [31, 3]
# 11     [24, 1]
# 12     [30, 3]
# 13     [27, 3]
# 14     [36, 3]
# 15     [32, 2]
# 16     [20, 3]
# 17     [28, 2]
# 18     [55, 3]
# 19     [23, 3]
# 20     [20, 2]
# 21     [21, 2]
# 22     [27, 3]
# 23     [28, 1]
# 24     [29, 3]
# 25     [57, 3]
# 26     [23, 3]
# 27     [30, 1]
# 28     [29, 3]
# 29     [19, 3]
#         ...
# 861    [27, 2]
# 862    [51, 1]
# 863    [33, 3]
# 864    [22, 2]
# 865    [24, 2]
# 866    [28, 2]
# 867    [36, 1]
# 868    [27, 3]
# 869    [31, 3]
# 870    [17, 3]
# 871    [48, 1]
# 872    [24, 1]
# 873    [27, 3]
# 874    [37, 2]
# 875    [32, 3]
# 876    [29, 3]
# 877    [20, 3]
# 878    [18, 3]
# 879    [45, 1]
# 880    [44, 2]
# 881    [18, 3]
# 882    [28, 3]
# 883    [29, 2]
# 884    [22, 3]
# 885    [36, 3]
# 886    [21, 2]
# 887    [28, 1]
# 888    [40, 3]
# ...

# %%
x1 = [] #list of length of each name
x2 = [] # passenger class

# %%
for item in x:
    x1.append(item[0])
    x2.append(item[1])

# %%
df = pd.DataFrame({'Len': x1, 'Class': x2})

# %%
df.head()
# Out:
#    Len  Class
# 0   23      3
# 1   51      1
# 2   22      3
# 3   44      1
# 4   24      3

# %%
groups = df.groupby('Class')

# %%
groups.max()
# Out:
#        Len
# Class
# 1       82
# 2       67
# 3       57

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic['Length'] = titanic['Name'].str.len()
newdf = titanic[['Name', 'Pclass', 'Length']]
groups = newdf.groupby('Pclass')
groups[['Length', 'Name']].max()
# Out:
#         Length                         Name
# Pclass
# 1           82     Young, Miss. Marie Grice
# 2           67    del Carlo, Mr. Sebastiano
# 3           57  van Melkebeke, Mr. Philemon

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Length
# 0      0         A/5 21171   7.2500   NaN        S      23
# 1      0          PC 17599  71.2833   C85        C      51
# 2      0  STON/O2. 3101282   7.9250   NaN        S      22
# 3      0            113803  53.1000  C123        S      44
# ...

# %%
max(titanic['Fare'])
# Out:
# 512.3292

# %%
titanic[titanic['Fare']==max(titanic['Fare'])]
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 258          259         1       1                    Ward, Miss. Anna
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
# 737          738         1       1              Lesurer, Mr. Gustave J
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked  \
# 258  female  35.0      0      0  PC 17755  512.3292          NaN        C
# 679    male  36.0      0      1  PC 17755  512.3292  B51 B53 B55        C
# 737    male  35.0      0      0  PC 17755  512.3292         B101        C
#
#      Length
# 258      16
# 679      34
# 737      22

# %%
gold = pd.DataFrame({'Country': ['USA', 'France', 'Russia'],
                         'Medals': [15, 13, 9]}
                    )
silver = pd.DataFrame({'Country': ['USA', 'Germany', 'Russia'],
                        'Medals': [29, 20, 16]}
                    )
bronze = pd.DataFrame({'Country': ['France', 'USA', 'UK'],
                        'Medals': [40, 28, 27]}
                    )

# %% [markdown]
# Question : Given three data frames containing the number of gold, silver, and bronze Olympic medals won by some countries, determine the total number of medals won by each country.
# Note: All the three data frames don’t have all the same countries. So, ensure you use the ‘fill_value’ argument (set it to zero), to avoid getting NaN values. Also, ensure you sort the final dataframe, according to the total medal count in descending order.

# %%
df = pd.concat([gold, silver, bronze], keys=['gold', 'silver', 'bronze']).groupby('Country').sum()

# %%
df.sort_values(by='Medals', ascending=False)
# Out:
#          Medals
# Country
# Germany      20
# Russia       25
# UK           27
# France       53
# USA          72
